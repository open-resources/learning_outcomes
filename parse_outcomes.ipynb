# %%
import yaml
import pathlib

# %%
mdtext = pathlib.Path('Masterlist_Topics_Outcomes.yml').read_text()

# %%
# Deal with YAML header
outcomes = yaml.safe_load(mdtext)

# %%
list(outcomes['Math']['Topic Outcome'])
# Out:
# ['Does this need quotes?', "Maybe if I have quotes' like this?"]

# %%
for k1,v1 in outcomes.items():
    for k2,v2 in v1.items():
        try:
            for k3,v3 in v2.items():
                print(k1+','+k2+',',k3)
        except AttributeError:
            print(k1+','+k2)
# Out:
# Math,Topic Outcome
# Math,Graphs
# Math,Significant Figures
# Math,Order of Magnitude
# Math,Algebra, Subtopic Outcome
# Math,Algebra, Dimensional Analysis
# Math,Limits
# Math,Derivatives, Subtopic Outcome
# Math,Derivatives, Slope
# Math,Derivatives, Product rule
# Math,Derivatives, Quotient Rule
# Math,Derivatives, Power Rule
# Math,Derivatives, Chain rule
# Math,Derivatives, Max/Min
# Math,Derivatives, Increasing/Decreasing Test
# Math,Derivatives, First Derivative Test
# Math,Derivatives, Second Derivative Test
# Math,Integrals, Subtopic Outcome
# Math,Integrals, Area Under Curve
# Math,Integrals, Area Between Two Curves
# Math,Integrals, Substitution Rule
# Math,Integrals, Integration by Parts
# Math,Integrals, Trigonometric Substitution
# Math,Integrals, Partial Fractions
# Math,Exponential Functions, Subtopic Outcome
# Math,Exponential Functions, Derivative
# Math,Exponential Functions, Integral
# Math,Logarithmic Functions, Subtopic Outcome
# Math,Logarithmic Functions, Derivative
# Math,Logarithmic Functions, Integral
# Math,System of Equations, Subtopic Outcome
# Math,System of Equations, Set Up
# Math,System of Equations, Solve
# Math,Quadratic formula, Subtopic Outcome
# Math,Quadratic formula, Non-Physical Roots
# Math,Polar Coordinates
# Vectors,Topic Outcome
# Vectors,Notation
# Vectors,Scalars
# Vectors,Vectors
# Vectors,Properties of Vectors
# Vectors,Coordinate System and Vector Components
# Vectors,Vector Algebra
# Vectors,Dot Product
# Vectors,Cross Product
# Kinematics(1D),Topic Outcome
# Kinematics(1D),Motion Diagrams
# Kinematics(1D),Position
# Kinematics(1D),Displacement
# Kinematics(1D),Speed
# Kinematics(1D),Velocity, Subtopic Outcome
# Kinematics(1D),Velocity, Average
# Kinematics(1D),Velocity, Instantaneous
# Kinematics(1D),Acceleration, Subtopic Outcome
# Kinematics(1D),Acceleration, Average
# Kinematics(1D),Acceleration, Instantaneous
# Kinematics(1D),Uniform Motion
# Kinematics(1D),Non-Uniform Motion (Constant Acceleration)
# Kinematics(1D),Free Fall
# Kinematics(2D and 3D),Topic Outcome
# Kinematics(2D and 3D),Displacement Vector
# Kinematics(2D and 3D),Velocity Vector
# Kinematics(2D and 3D),Acceleration Vector
# Kinematics(2D and 3D),Projectile Motion
# Kinematics(2D and 3D),Uniform Circular Motion, Subtopic Outcome
# Kinematics(2D and 3D),Uniform Circular Motion, Velocity
# Kinematics(2D and 3D),Uniform Circular Motion, Acceleration
# Kinematics(2D and 3D),Non-Uniform Circular Motion, Subtopic Outcome
# Kinematics(2D and 3D),Non-Uniform Circular Motion, Angular Acceleration
# Force,Topic Outcome
# Force,Types of Forces
# Force,Free Body Diagrams
# Force,Newton's First Law
# Force,Newton's Second Law
# Force,Newton's Third Law, Subtopic Outcome
# Force,Newton's Third Law, Ropes and Pulleys
# Force,Equilibrium
# Force,Mass, Weight and Gravity
# Force,Friction
# Force,Drag, Subtopic Outcome
# Force,Drag, Terminal Velocity
# Force,Drag, Projectile Motion with Drag
# Force,Springs, Subtopic Outcome
# Force,Springs, Hooke's Law
# Force,Dynamics of Circular Motion, Subtopic Outcome
# Force,Dynamics of Circular Motion, Centripetal Force
# Force,Dynamics of Circular Motion, Uniform
# Force,Dynamics of Circular Motion, Non-Uniform
# Momentum,Topic Outcome
# Momentum,Momentum, Subtopic Outcome
# Momentum,Momentum, Linear
# Momentum,Momentum, Angular
# Momentum,Impulse
# Momentum,Collisions, Subtopic Outcome
# Momentum,Collisions, Elastic
# Momentum,Collisions, Inelastic
# Momentum,Collisions, Explosions
# Momentum,Conservation of Momentum, Subtopic Outcome
# Momentum,Conservation of Momentum, Linear
# Momentum,Conservation of Momentum, Angular
# Momentum,2D Collisions
# Energy,Topic Outcome
# Energy,Kinetic Energy
# Energy,Potential Energy, Subtopic Outcome
# Energy,Potential Energy, Gravitational Potential Energy
# Energy,Potential Energy, Elastic Potential Energy
# Energy,Energy Diagrams
# Energy,Conservation of Energy, Subtopic Outcome
# Energy,Conservation of Energy, Conservative Forces
# Energy,Conservation of Energy, Non-Conservative Forces
# Work,Topic Outcome
# Work,Work
# Work,Work-Energy Theorem
# Work,Power
# Rigid Body Rotation,Topic Outcome
# Rigid Body Rotation,Rotational Motion, Subtopic Outcome
# Rigid Body Rotation,Rotational Motion, Relating Rotational to Translational Motion
# Rigid Body Rotation,Rolling Motion, Subtopic Outcome
# Rigid Body Rotation,Rolling Motion, Without Slipping
# Rigid Body Rotation,Rolling Motion, With Slipping
# Rigid Body Rotation,Center of Mass
# Rigid Body Rotation,Rotational Energy, Subtopic Outcome
# Rigid Body Rotation,Rotational Energy, Moment of Inertia
# Rigid Body Rotation,Rotational Energy, Parallel-Axis Theorem
# Rigid Body Rotation,Torque
# Rigid Body Rotation,Rotational Dynamics, Subtopic Outcome
# Rigid Body Rotation,Rotational Dynamics, Newton's Second Law for Rotational Motion
# Rigid Body Rotation,Rotation about a Fixed Axis
# Rigid Body Rotation,Static Equilibrium
# Rigid Body Rotation,Work For Rotational Motion
# Rigid Body Rotation,Power For Rotational Motion
# Rigid Body Rotation,Precession
# Gravitation,Topic Outcome
# Gravitation,Newton's Law of Gravity
# Gravitation,Orbits
# Gravitation,Kepler's Laws, Subtopic Outcome
# Gravitation,Kepler's Laws, Kepler's First Law
# Gravitation,Kepler's Laws, Kepler's Second Law
# Gravitation,Kepler's Laws, Kepler's Third Law
# Gravitation,Tides
# Gravitation,Einstein's Theory of Gravity
# Fluids,Topic Outcome
# Fluids,Density
# Fluids,Pressure
# Fluids,Pascal's Law, Subtopic Outcome
# Fluids,Pascal's Law, Hydraulics
# Fluids,Archimedes' Principle, Subtopic Outcome
# Fluids,Archimedes' Principle, Buoyancy
# Fluids,Fluid Dynamics, Subtopic Outcome
# Fluids,Fluid Dynamics, Flow Rate
# Fluids,Fluid Dynamics, Laminar/Turbulent Flow
# Fluids,Fluid Dynamics, Viscosity
# Fluids,Fluid Dynamics, Equation of Continuity
# Fluids,Fluid Dynamics, Bernoulli's Equation
# Elasticity,Topic Outcome
# Elasticity,Stress
# Elasticity,Strain
# Elasticity,Elastic Modulus
# Elasticity,Plasticity
